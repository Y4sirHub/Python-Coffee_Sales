# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/coffee-sales/index.csv

# %%
# pip install matplotlib

import matplotlib.pyplot as plt

# %%
df_coffee = pd.read_csv('/kaggle/input/coffee-sales/index.csv')
df_coffee
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 1203  2024-08-08  2024-08-08 12:43:19.558      card  ANON-0000-0000-0141
# 1204  2024-08-08  2024-08-08 12:44:14.953      card  ANON-0000-0000-0141
# 1205  2024-08-08  2024-08-08 16:57:53.266      card  ANON-0000-0000-0473
# 1206  2024-08-08  2024-08-08 17:17:51.749      card  ANON-0000-0000-0474
# 1207  2024-08-08  2024-08-08 21:25:59.265      card  ANON-0000-0000-0311
#
#       money          coffee_name
# 0     38.70                Latte
# ...

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1208 non-null   object
#  1   datetime     1208 non-null   object
#  2   cash_type    1208 non-null   object
#  3   card         1119 non-null   object
#  4   money        1208 non-null   float64
#  5   coffee_name  1208 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 56.8+ KB

# %%
unique_coffee_names = df_coffee['coffee_name'].unique()
print(unique_coffee_names)
# Out:
# ['Latte' 'Hot Chocolate' 'Americano' 'Americano with Milk' 'Cocoa'
#  'Cortado' 'Espresso' 'Cappuccino']

# %%
# Sample data
 
categories = df_coffee['coffee_name']
values = df_coffee['money']
 
# Create a bar plot
plt.figure(figsize=(10,6))
plt.bar(categories, values, color ='peru', width = 0.5, edgecolor = 'black')
plt.title('Amount generated per coffee variant',fontweight = 'bold', color = 'saddlebrown', fontsize = '15')

## Customisation

# Adding axis labels
plt.xlabel('Coffee Name', fontweight = 'bold', color = 'sienna', fontsize = '10')
plt.xticks(rotation = 45)
plt.ylabel('Amount', fontweight = 'bold', color = 'sienna', fontsize = '10')
plt.legend()

# Showing the plot
plt.show()

# %%
# pip install seaborn

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Scatter Plot

# %%
# Scatter Plot for Cash Type

plt.figure(figsize=(4,6))
sns.scatterplot(data=df_coffee, x='cash_type', y='money', hue='coffee_name',palette='coolwarm')
plt.legend(title='Payment method',title_fontsize='08', fontsize='06',bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Scatter Plot for Coffee Name

plt.figure(figsize=(12,8))
sns.scatterplot(data=df_coffee, x='coffee_name', y='money', hue='cash_type',palette='coolwarm')
plt.legend(title='Payment method',title_fontsize='08', fontsize='06',loc='lower left')
plt.show()

# %%
sns.set_theme(style='white')
plt.figure(figsize=(4,6))
sns.scatterplot(data=df_coffee, x='cash_type', y='coffee_name', hue='money',palette='coolwarm')
#plt.legend(title='Payment method',title_fontsize='08', fontsize='06',bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
sns.set_theme(style="white")
plt.figure(figsize=(5,7))
sns.relplot(data=df_coffee, x='cash_type', y='coffee_name', size='money', hue='money', palette = 'coolwarm')
#plt.legend(title='Payment method',title_fontsize='08', fontsize='06',bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
sns.set_theme(style="dark")
plt.figure(figsize=(5,7))
sns.relplot(data=df_coffee, x='cash_type', y='coffee_name', size='money', hue='money', palette = 'coolwarm')
#plt.legend(title='Payment method',title_fontsize='08', fontsize='06',bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
df_coffee
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 1203  2024-08-08  2024-08-08 12:43:19.558      card  ANON-0000-0000-0141
# 1204  2024-08-08  2024-08-08 12:44:14.953      card  ANON-0000-0000-0141
# 1205  2024-08-08  2024-08-08 16:57:53.266      card  ANON-0000-0000-0473
# 1206  2024-08-08  2024-08-08 17:17:51.749      card  ANON-0000-0000-0474
# 1207  2024-08-08  2024-08-08 21:25:59.265      card  ANON-0000-0000-0311
#
#       money          coffee_name
# 0     38.70                Latte
# ...

# %%
df_coffee['day']=pd.DatetimeIndex(df_coffee['datetime']).day

# %%
# Line Plot

sns.set_theme(style="white")
plt.figure(figsize=(10,6))
sns.lineplot(data=df_coffee, x='day', y='money', hue='cash_type',palette='coolwarm')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# line plot
sns.set_theme(style="white")
plt.figure(figsize=(10,6))
sns.lineplot(data=df_coffee, x='day', y='money', hue='cash_type',palette='coolwarm');
plt.savefig('test1.png')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
